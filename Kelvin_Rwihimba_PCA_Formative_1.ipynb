# %% [markdown]
# <a href="https://colab.research.google.com/github/Kelvin364/ALX_DATA-SCIENCE/blob/main/Kelvin_Rwihimba_PCA_Formative_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Formative Assignment: Advanced Linear Algebra (PCA)
# This notebook will guide you through the implementation of Principal Component Analysis (PCA). Fill in the missing code and provide the required answers in the appropriate sections. You will work with a dataset that is Africanized .
#
# Make sure to display outputs for each code cell when submitting.

# %% [markdown]
# ### Step 1: Load and Standardize the Data
# Before applying PCA, we must standardize the dataset. Standardization ensures that all features have a mean of 0 and a standard deviation of 1, which is essential for PCA.
# Fill in the code to standardize the dataset.
#
# STRICTLY - Write code that implements standardization based on the image below
#
# <img src='data:image/jpeg;base64,...'/>

# %%
# Step 1: Load and Standardize the data (use of numpy only allowed)
import numpy as np
data = np.loadtxt('/content/heart.csv', delimiter=',', skiprows=1)

#standardizing the data
mean_all = np.mean(data , axis=0)
std_all = np.std(data , axis=0)

standardized_data = (data - mean_all) / std_all
standardized_data[:5]
# Out:
# array([[ 0.9521966 ,  0.68100522,  1.97312292,  0.76395577, -0.25633371,
#          2.394438  , -1.00583187,  0.01544279, -0.69663055,  1.08733806,
#         -2.27457861, -0.71442887, -2.14887271,  0.91452919],
#        [-1.91531289,  0.68100522,  1.00257707, -0.09273778,  0.07219949,
#         -0.41763453,  0.89896224,  1.63347147, -0.69663055,  2.12257273,
#         -2.27457861, -0.71442887, -0.51292188,  0.91452919],
#        [-1.47415758, -1.46841752,  0.03203122, -0.09273778, -0.81677269,
#         -0.41763453, -1.00583187,  0.97751389, -0.69663055,  0.31091206,
#          0.97635214, -0.71442887, -0.51292188,  0.91452919],
#        [ 0.18017482,  0.68100522,  0.03203122, -0.66386682, -0.19835726,
#         -0.41763453,  0.89896224,  1.23989692, -0.69663055, -0.20670527,
#          0.97635214, -0.71442887, -0.51292188,  0.91452919],
#        [ 0.29046364, -1.46841752, -0.93851463, -0.66386682,  2.08204965,
# ...

# %% [markdown]
# ### Step 3: Calculate the Covariance Matrix
# The covariance matrix helps us understand how the features are related to each other. It is a key component in PCA.

# %%
# Step 3: Calculate the Covariance Matrix
cov_matrix = np.cov(standardized_data.T)  # Calculate covariance matrix
cov_matrix
# Out:
# array([[ 1.00331126, -0.09877258, -0.06888034,  0.28027591,  0.2143855 ,
#          0.12170933, -0.1165957 , -0.39984155,  0.09712136,  0.21070797,
#         -0.16937323,  0.27724123,  0.06822655, -0.2261852 ],
#        [-0.09877258,  1.00331126, -0.0495163 , -0.0569568 , -0.19856751,
#          0.0451809 , -0.05838897, -0.04416567,  0.1421329 ,  0.09641107,
#         -0.03081226,  0.11865301,  0.2107366 , -0.28186683],
#        [-0.06888034, -0.0495163 ,  1.00331126,  0.0477654 , -0.07715904,
#          0.09475676,  0.04456768,  0.29674147, -0.39558583, -0.1497243 ,
#          0.120113  , -0.18165254, -0.16227112,  0.43523468],
#        [ 0.28027591, -0.0569568 ,  0.0477654 ,  1.00331126,  0.12358207,
#          0.17811839, -0.11448061, -0.04685236,  0.06784001,  0.19385626,
#         -0.12187682,  0.10172471,  0.06241588, -0.14541103],
#        [ 0.2143855 , -0.19856751, -0.07715904,  0.12358207,  1.00331126,
# ...

# %% [markdown]
# ### Step 4: Perform Eigendecomposition
# Eigendecomposition of the covariance matrix will give us the eigenvalues and eigenvectors, which are essential for PCA.
# Fill in the code to compute the eigenvalues and eigenvectors of the covariance matrix.

# %%
# Step 4: Perform Eigendecomposition
eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)  # Perform eigendecomposition
eigenvalues, eigenvectors
# Out:
# (array([3.31240732, 1.57737062, 1.23610856, 1.2106344 , 0.3691578 ,
#         0.37310751, 0.43145758, 1.02541325, 0.97338089, 0.53617184,
#         0.86609311, 0.77866275, 0.73160926, 0.62478273]),
#  array([[-0.25395987,  0.44468536,  0.06690997, -0.06635435, -0.14797767,
#           0.19228174, -0.52479585,  0.30674004,  0.12641772, -0.13050535,
#          -0.21711854,  0.25177975,  0.39611172, -0.00765511],
#         [-0.12203775, -0.39157094, -0.55956069,  0.0812111 ,  0.23326173,
#           0.04637046, -0.08310562, -0.05612852, -0.0620435 , -0.23921669,
#          -0.15092487,  0.16648215,  0.23014486,  0.53002082],
#         [ 0.27455103,  0.26756302, -0.22733463,  0.37876048, -0.27265906,
#           0.02340343,  0.22270369, -0.15936941,  0.19839869,  0.53602415,
#          -0.21899636, -0.05151167,  0.3122545 ,  0.18222332],
#         [-0.14736218,  0.44342889, -0.19892862,  0.08977285,  0.16655686,
#           0.00930944,  0.2097804 , -0.18688032,  0.18134578, -0.04901491,
# ...

# %% [markdown]
# ### Step 5: Sort Principal Components
# Sort the eigenvectors based on their corresponding eigenvalues in descending order. The higher the eigenvalue, the more important the eigenvector.
# Complete the code to sort the eigenvectors and print the sorted components.
#
# <a url ='https://www.youtube.com/watch?v=vaF-1xUEXsA&t=17s'>How Is Explained Variance Used In PCA?'<a/>

# %%
# Step 5: Sort Principal Components
sorted_indices = np.argsort(eigenvalues)[::-1]  # Sort eigenvalues in descending order
sorted_eigenvectors = eigenvectors[:, sorted_indices]  # Sort eigenvectors accordingly
sorted_eigenvectors
# Out:
# array([[-0.25395987,  0.44468536,  0.06690997, -0.06635435,  0.30674004,
#          0.12641772, -0.21711854,  0.25177975,  0.39611172, -0.00765511,
#         -0.13050535, -0.52479585,  0.19228174, -0.14797767],
#        [-0.12203775, -0.39157094, -0.55956069,  0.0812111 , -0.05612852,
#         -0.0620435 , -0.15092487,  0.16648215,  0.23014486,  0.53002082,
#         -0.23921669, -0.08310562,  0.04637046,  0.23326173],
#        [ 0.27455103,  0.26756302, -0.22733463,  0.37876048, -0.15936941,
#          0.19839869, -0.21899636, -0.05151167,  0.3122545 ,  0.18222332,
#          0.53602415,  0.22270369,  0.02340343, -0.27265906],
#        [-0.14736218,  0.44342889, -0.19892862,  0.08977285, -0.18688032,
#          0.18134578,  0.32566901,  0.60454889, -0.34193253,  0.05930643,
#         -0.04901491,  0.2097804 ,  0.00930944,  0.16655686],
#        [-0.09219679,  0.35896621,  0.1807147 , -0.50929857, -0.32139792,
# ...

# %% [markdown]
# ### Step 6: Project Data onto Principal Components
# Now that we’ve selected the number of components, we will project the original data onto the chosen principal components.
# Fill in the code to perform the projection.

# %%
# Step 6: Project Data onto Principal Components
num_components = 2 # Decide on the number of principal components to keep
data_centered = data - np.mean(data, axis=0)
reduced_data = np.dot(standardized_data, sorted_eigenvectors[:, :num_components])  # Project data onto the principal components
reduced_data[:5]
# Out:
# array([[ 0.05173911,  2.62402204],
#        [ 0.81744059, -0.73037458],
#        [ 2.05759932, -0.03909845],
#        [ 1.90304318, -0.59670088],
#        [ 0.76837062,  0.4125455 ]])

# %% [markdown]
# ### Step 7: Output the Reduced Data
# Finally, display the reduced data obtained by projecting the original dataset onto the selected principal components.

# %%
# Step 7: Output the Reduced Data
print(f'Reduced Data Shape: {reduced_data.shape}')  # Display reduced data shape
reduced_data[:5]  # Display the first few rows of reduced data
# Out:
# Reduced Data Shape: (303, 2)
# array([[ 0.05173911,  2.62402204],
#        [ 0.81744059, -0.73037458],
#        [ 2.05759932, -0.03909845],
#        [ 1.90304318, -0.59670088],
#        [ 0.76837062,  0.4125455 ]])

# %% [markdown]
# ### Step 8: Visualize Before and After PCA
# Now, let's plot the original data and the data after PCA to compare the reduction in dimensions visually.

# %%
import matplotlib.pyplot as plt

# Create figure with two subplots side by side
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Plot original data (first two features for simplicity)
axes[0].scatter(standardized_data[:, 0], standardized_data[:, 1],
                c=data[:, -1], cmap='viridis', alpha=0.6, edgecolors='k', s=50)
axes[0].set_xlabel('Feature 1 (Standardized)')
axes[0].set_ylabel('Feature 2 (Standardized)')
axes[0].set_title('Original Data (First 2 Features)')
axes[0].grid(True, alpha=0.3)

# Plot reduced data after PCA
axes[1].scatter(reduced_data[:, 0], reduced_data[:, 1],
                c=data[:, -1], cmap='viridis', alpha=0.6, edgecolors='k', s=50)
axes[1].set_xlabel('PC1')
axes[1].set_ylabel('PC2')
axes[1].set_title('Data After PCA (First 2 PCs)')
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
